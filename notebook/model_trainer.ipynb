# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\WAFER_FAULT_DETECTION\artifacts\wafer.csv')

# %%
df.head(5)
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2      0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3      0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4      0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
# 2        -1
# 3        -1
# 4        -1
#
# [5 rows x 592 columns]

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Data Profiling ", explorative=True)
profile.to_file('report.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 profile = ProfileReport(df, title="Data Profiling ", explorative=True)
#       3 profile.to_file('report.html')
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
pip install pkg_resources
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement pkg_resources (from versions: none)
# ERROR: No matching distribution found for pkg_resources

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.68.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
#pip install ydata-profiling
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Data Profiling", explorative=True)
profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #pip install ydata-profiling
# ----> 2 from ydata_profiling import ProfileReport
#       4 profile = ProfileReport(df, title="Data Profiling", explorative=True)
#       5 profile.to_file("report.html")
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'
